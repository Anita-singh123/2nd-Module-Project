# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # **Project Name**    -
# Credit Score Classification

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 -** Aneeta kumari
# ##### **Team Member 2 -** N/A
# ##### **Team Member 3 -** N/A
# ##### **Team Member 4 -** N/A

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on analyzing customer financial data to understand the factors that influence credit scores and to identify patterns associated with Good, Standard, and Poor credit ratings. The dataset contains 100,000 records and 28 variables, covering important customer information such as age, annual income, number of bank accounts, credit cards, loans, delayed payments, outstanding debt, credit utilization ratio, credit inquiries, payment behaviour, and credit score. The main objective of the project is to perform exploratory data analysis (EDA), clean and prepare the data, discover meaningful relationships between variables, and generate insights that can help understand customer creditworthiness.
#
# The data preparation process involved checking the dataset structure, data types, missing values, duplicate records, unique values, and possible inconsistencies. The dataset did not contain complete duplicate rows or pandas missing values. However, some categorical variables contained values such as “NM” (Not Mentioned) and “No Data”, which required appropriate interpretation during analysis. Columns such as ID, SSN, and Name were considered less useful for analytical purposes because they are identification-related rather than meaningful financial predictors. Numerical variables were also examined for unusual values and potential outliers.
#
# Several new features and categories can be created to make the dataset more suitable for analysis. For example, loan information can be summarized using a Loan Count, while financial ratios such as Debt-to-Income Ratio and EMI-to-Income Ratio can provide additional information about a customer's financial burden. Credit history can also be converted into years for easier interpretation. These transformations help improve the understanding of customer financial behaviour.
#
# A Correlation Heatmap was used to understand relationships between numerical variables. The analysis showed that Number of Loans and Outstanding Debt have a relatively strong positive correlation, while Credit Inquiries and Outstanding Debt also show a positive relationship. This indicates that customers with more loans or credit inquiries tend to have higher outstanding debt.
#
# Overall, the project provides a detailed understanding of customer financial characteristics and their relationship with credit scores. The analysis demonstrates how data cleaning, feature engineering, exploratory data analysis, correlation analysis, and visualization can be used together to extract useful insights from financial data.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The objective of this project is to analyze customer financial data and identify the factors that influence credit scores. The dataset contains information about customers' income, loans, bank accounts, credit cards, delayed payments, outstanding debt, credit utilization, payment behaviour, credit mix, and other financial attributes.
#
# The main problem is to understand why customers receive different credit score categories — Good, Standard, or Poor. By performing data cleaning, preprocessing, exploratory data analysis, and visualization, we aim to discover meaningful patterns and relationships between financial variables and credit scores.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The main business objective of this project is to analyze customer financial data and identify the key factors that influence their credit score. The analysis aims to understand customer financial behaviour based on income, loans, credit card usage, outstanding debt, delayed payments, credit utilization, payment behaviour, and credit mix.
#
# The project will classify customers into Good, Standard, and Poor credit score categories and identify patterns associated with each category. These insights can help financial institutions assess customer creditworthiness, identify high-risk customers, and make better credit-related decisions.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
df=pd.read_csv('/content/drive/MyDrive/2nd module Project/dataset.csv')

# %% [markdown]
# ### Dataset First View

# %%
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape

# %% [markdown]
# ### Dataset Information

# %%
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
df.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isnull().sum()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains 100,000 rows and 28 columns.
# It contains information about customers' income, loans, bank accounts, credit cards, payments, debt, credit history, and credit score.
# The target variable is Credit_Score, which has three categories:
# Standard: 53,174 records
# Poor: 28,998 records
# Good: 17,828

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset contains 28 variables that describe customers' personal, financial, credit, and payment-related information. The target variable is Credit_Score, which classifies customers into Good, Standard, and Poor categories.
#
#
# 1. ID :- Unique ID for each record.
# 2. Customer_ID :- Unique ID assigned to each customer.
# 3. Month :- Month of the financial record.
# 4. Name :- Customer's name.
# 5. Age :- Age of the customer.
# 6. SSN :- Social Security Number of the customer.
# 7. Occupation :- Customer's occupation or profession.
# 8. Annual_Income :- Total income earned by the customer annually.
# 9. Monthly_Inhand_Salary :- Monthly salary available to the customer.
# 10. Num_Bank_Accounts :- Number of bank accounts owned by the customer.
# 11. Num_Credit_Card :- Number of credit cards owned by the customer.
# 12. Interest_Rate :- Interest rate applicable to the customer's credit/loan accounts.
# 13. Num_of_Loan :- Number of loans taken by the customer.
# 14. Type_of_Loan :- Types of loans held by the customer.
# 15. Delay_from_due_date :- Number of days payments were delayed beyond the due date.
# 16. Num_of_Delayed_Payment :- Number of delayed payments made by the customer.
# 17. Changed_Credit_Limit :- Change in the customer's credit limit.
# 18. Num_Credit_Inquiries :- Number of credit inquiries made for the customer.
# 19. Credit_Mix  :- Indicates the quality or combination of the customer's credit accounts.
# 20. Outstanding_Debt :- Total amount of debt currently outstanding.
# 21. Credit_Utilization_Ratio :- Percentage of available credit being used by the customer.
# 22. Credit_History_Age :- Length of the customer's credit history.
# 23. Payment_of_Min_Amount :- Indicates whether the customer pays the minimum amount due.
# 24. Total_EMI_per_month :- Total EMI paid by the customer per month.
# 25. Amount_invested_monthly :- Amount invested by the customer each month.
# 26. Payment_Behaviour :- Customer's spending and payment behaviour.
# 27. Monthly_Balance :- Monthly balance maintained by the customer.
# 28. Credit_Score :- Target variable representing the customer's credit category: Good, Standard, or Poor.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable
_v=df.columns.tolist()
for i in _v:
  print(f'{i}:{df[i].nunique()}')

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
for i in _v:
  print(i,df[i].dtype)

# %%
df.head()

# %%
df["Num_Bank_Accounts"] = df["Num_Bank_Accounts"].astype(int)

# %%
print(df['Num_Bank_Accounts'].dtype)

# %%
df['Spending_Level'] = df['Payment_Behaviour'].str.split('_').str[0]

# %%
df['Payment_Value'] = df['Payment_Behaviour'].str.extract(
    r'(Small|Medium|Large)'
)

# %%
df['Payment_Value']

# %%
count_df=df['Credit_Score'].value_counts().reset_index()
count_df.columns=['credit_score','count']
print(count_df)

# %%
sns.barplot( data=count_df, x='credit_score',y='count')
plt.title('Average Total Bill by day')
plt.xlabel('credit_score')
plt.ylabel('Average of total bill')
plt.show()

# %%
monthly = pd.crosstab(
    df['Month'],
    df['Credit_Score'],
    normalize='index'
) * 100

monthly.round(2)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# First, i performed data cleaning and preprocessing on the dataset, i checked the shape, data types, missing values, duplicate records, and unique values of all columns, i handled inconsistent values and converted the columns info appropriate data types wherever required, i also checked numerical columns for outliers using descriptive statistics and visualizations,

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(10, 6))
sns.countplot(df,x=df['Credit_Score'])
plt.title('Credit Score Distribution  ')
plt.xlabel('credit score')
plt.ylabel('count')
plt.show()

# %%
df.columns

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a Countplot (Bar Chart) because Credit_Score is a categorical variable with three categories: Good, Standard, and Poor.
#
# It clearly shows the number of customers in each credit-score category.
# It makes it easy to compare the three categories.
# We can quickly identify the most common and least common credit score.
# It helps us understand whether the target variable is balanced or imbalanced.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the Standard credit score category has the highest number of records, followed by Poor and Good. This indicates that most customers have a Standard credit score, while relatively fewer customers have a Good credit score. The distribution of credit scores is imbalanced, which should be considered while building a predictive model.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights can help the client make better credit-risk decisions. Since most customers have a Standard credit score, the client can focus on understanding their financial behaviour and take steps to help suitable customers improve their creditworthiness.
#
# Positive business impact:
# *  Identify Poor credit-score customers and manage credit risk.
# *  Help Standard-score customers improve their credit profile.
# *  Make better lending and credit approval decisions.
# *  Reduce the possibility of loan defaults and financial losses.
#
# the relatively high number of Poor credit-score records can indicate a potential business risk. Customers with Poor credit scores may have a higher probability of delayed payments or repayment problems. If the company approves credit without proper risk assessment, it may lead to higher defaults, financial losses, and increased collection costs.
#
# However, this insight does not directly mean negative growth. Instead, it highlights an area where the client should take preventive action.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(10, 6))
sns.countplot(df,x=df['Occupation'],color='green')
plt.title('Occupation Distribution')
plt.xlabel('Occupation')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a Countplot because Occupation is a categorical variable. A Countplot is suitable for showing the frequency of records in each occupation and makes it easy to compare the distribution of customers across different occupations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Balanced Occupational Representation: The dataset shows a fairly uniform and even distribution of customers across various professions (such as Scientists, Teachers, Engineers, Developers, Lawyers, etc).
# * No Single-Group Dominance: No single occupation dominates the customer base, indicating that the dataset is unbiased regarding profession-specific data.
# *  Diverse Demographic Base: The customer pool represents a healthy mix of both salaried professionals and specialized workers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
#
# *  Diversified Risk Portfolio: A balanced occupational distribution ensures that the institution’s credit portfolio is not overly exposed to downturns in any single industry or employment sector.
# *  Segment-Specific Financial Products: The insights allow financial institutions to design tailored credit cards, customized loan offers, and flexible repayment terms matched to the specific income stability and cash flow patterns of different professions.
#
# Insights Leading to Negative Growth & Justification:
#
#
#
# *  Risk of Profession-Based Bias: Relying strictly on occupation as a primary factor for credit approval—rather than evaluating individual financial behavior (e.g., debt-to-income ratio, payment history)—can lead to misjudging creditworthiness.
# *  Lost Business Opportunities: Unjustly penalizing or rejecting applicants from professions perceived as high-risk can alienate creditworthy individuals, leading to customer churn, loss of market share, and negative revenue growth.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(12, 6))
sns.barplot(df,y=df['Annual_Income'],x='Credit_Score')
plt.title('Annual_Income vs Credit_Score')
plt.xlabel('Credit_Score')
plt.ylabel('Average Annual_Income')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a Barplot because it is suitable for comparing the average Annual Income across different Credit Score categories. It makes it easy to identify differences in income levels among customers with Good, Standard, and Poor credit scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.Customers with a Good credit score have the highest average annual income, around 65,000.
#
# 2.Customers with a Standard credit score have an average annual income of around 51,000.
#
# 3.Customers with a Poor credit score have the lowest average annual income, around 41,000.
#
# 4.Overall, the chart suggests a positive relationship between annual income and credit score—higher-income customers tend to have better credit scores.
#
# 5.The difference between Good and Poor credit-score groups is quite large, roughly 24,000 in average annual income.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help create a positive business impact, but there is also a potential negative-growth concern.
#
# Positive business impact:-
#
# * Customers with Good credit scores have the highest average income (~65,000). This indicates that higher-income customers may be more financially reliable.
# * The business can use this insight to target and retain financially stronger customers, offer suitable loan/credit products, and design premium services for higher-income customers.
# * Understanding the relationship between income and credit score can also help improve customer segmentation and credit-risk decisions.
#
#
# Negative business impact:-
#
#
#
# * Customers with Poor credit scores have the lowest average income (~41,000).
# * This group may have lower repayment capacity, which could increase the risk of loan defaults or delayed payments if the business gives them excessive credit.
# * If the business completely avoids this segment, however, it could lose potential customers and revenue opportunities.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(10,6))
sns.barplot(df,y=df['Outstanding_Debt'],x='Credit_Score')
plt.title('Outstanding_Debt vs Credit_Score')
plt.xlabel('Credit_Score')
plt.ylabel('Average Outstanding_Debt')
plt.show()

# %%
df.columns

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is suitable because we are comparing the average value of a numerical variable across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights from the chart:-
#
#
#
# * Customers with a Poor credit score have the highest average outstanding debt, around 2,080.
# * Customers with a Standard credit score have average outstanding debt of around 1,280.
# * Customers with a Good credit score have the lowest average outstanding debt, around 800.
# * There is a clear pattern: as credit score decreases, average outstanding debt increases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help create a positive business impact, especially for credit-risk management.
#
# Positive business impact:-
#
# * Customers with Poor credit scores have the highest average outstanding debt (~2,080).
# * The business can identify this group as a higher-risk segment and take measures such as stricter credit limits, closer monitoring, or personalized repayment plans.
# * Customers with Good credit scores have much lower average outstanding debt (~800), so they may represent a lower-risk customer segment that can be targeted with suitable credit products.
# * Better risk management can help the business reduce potential loan defaults and financial losses.
#
# Negative business impact:-
#
# Yes, there is a potential negative impact if the insight is used incorrectly.
#
# * If the business completely avoids customers with Poor credit scores, it may lose potential customers and revenue.
# * Customers with poor credit scores may still be profitable if they have the ability and willingness to repay their debt.
# * Therefore, rejecting customers based only on credit score and outstanding debt could reduce the customer base and limit business growth.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(10, 6))
sns.scatterplot(df,x=df['Annual_Income'],y='Outstanding_Debt',hue='Credit_Score')
plt.title(' scatter plot of Annual Income vs. Outstanding Debt')
plt.xlabel('Annual Income')
plt.ylabel('Outstanding Debt')
plt.legend(title='Credit Score')
plt.show()

# %%
df.columns

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Annual_Income is a numerical variable.
# * Outstanding_Debt is also a numerical variable.
# * A scatter plot is best for showing the relationship or correlation between two numerical variables.
# * Each dot represents an individual customer, allowing us to see how Outstanding Debt changes with Annual Income.
# * I used Credit_Score as the hue so we can visually distinguish customers with Good, Standard, and Poor credit scores.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Higher income does not necessarily mean higher outstanding debt, but lower income combined with high debt may indicate greater financial risk.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:-
#
#  The insight can help the business manage credit risk by identifying customers with high outstanding debt, especially those with lower income.
#
# Negative business impact:-
#
#  High debt combined with low income may increase the risk of loan defaults or delayed repayments, which can cause financial losses.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(10, 6))
sns.barplot(df,y=df['Credit_Utilization_Ratio'],x='Credit_Score')
plt.title('Credit_Utilization_Ratio vs Credit_Score')
plt.xlabel('Credit_Score')
plt.ylabel('Credit_Utilization_Ratio')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a bar chart because Credit_Score is categorical (Good, Standard, Poor) and Credit_Utilization_Ratio is numerical.
#
# The bar chart makes it easy to compare the average credit utilization ratio across the three credit-score categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The Good credit-score group has the highest average credit utilization ratio, around 32.7.
# * The Standard group is slightly lower, around 32.3.
# * The Poor group has the lowest average, around 32.0.
# * The differences are very small, so credit utilization ratio appears to be almost similar across all three credit-score groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:-
#
# The insight can help the business understand that Credit Utilization Ratio is almost the same across all credit-score groups. Therefore, the business should not rely on this factor alone when assessing credit risk.
#
# Negative business impact:-
#
# There is a potential negative impact if the business assumes that credit utilization strongly determines credit score. Since the differences are very small, using it alone for credit decisions could lead to incorrect customer classification and missed business opportunities.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(10, 6))
sns.barplot(df,y=df['Num_of_Delayed_Payment'],x='Credit_Score')
plt.title('Num_of_Delayed_Payment vs Credit_Score')
plt.xlabel('Credit_Score')
plt.ylabel('Num_of_Delayed_Payment')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart is suitable for comparing a numerical value across different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights from the chart:-
#
# * Poor credit score customers have the highest average number of delayed payments, around 15.8.
# * Standard credit score customers have around 13.6 delayed payments.
# * Good credit score customers have the lowest, around 8.6.
# * This shows a clear relationship between delayed payments and credit score: more delayed payments are associated with poorer credit scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:-
#
# * The insight can help the business identify high-risk customers. Customers with more delayed payments can be monitored more closely, and the business can use suitable credit limits or repayment plans to reduce loan defaults and financial losses.
#
#
# Negative business impact:-
#
# * If the business completely rejects customers with frequent delayed payments, it may lose potential customers and revenue.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
sns.lineplot(data=monthly, markers=True)
# plt.title('Credit Score Trend by Month')
# plt.xlabel('Month')
# plt.ylabel('Credit Score')
# plt.legend(title='Credit Score')

# %%
df.columns

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a line chart because:
#
# * Month is a time-based variable.
# * A line chart clearly shows trends and changes over time.
# * It makes it easy to compare the Credit Score categories month by month.
# * It helps identify whether each category is increasing, decreasing, or remaining stable.
# A line chart is best for showing trends over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights from the chart:-
#
# * Standard credit score has the highest values, around 51–56.
# * Poor credit score is in the middle, around 28–30.
# * Good credit score has the lowest values, around 16–19.
# * The Standard category remains relatively stable but decreases slightly after Month 3.
# * Overall, the three credit-score categories show different levels and relatively stable trends over the months.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:-
#
# * The chart helps the business track how credit-score groups behave over time. The relatively stable trends can support regular monitoring and customer segmentation.
#
# Negative business impact:-
#
# * There is a potential risk if the business sees the Poor credit-score group remaining consistently higher than the Good group and does not address the underlying financial behavior. This could lead to higher credit risk and potential losses.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
plt.figure(figsize=(10, 6))
sns.countplot(df,x=df['Payment_Behaviour'],color='green',hue='Credit_Score')
plt.title('Payment Behaviour by Credit Score')
plt.xlabel('Payment Behaviour')
plt.ylabel('Number of Customers')
plt.legend(title='Credit Score')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Payment_Behaviour is a categorical variable.
# * Credit_Score is also categorical.
# * A count plot shows the number of customers in each payment-behaviour category.
# * Using hue='Credit_Score' makes it easy to compare customer counts across Good, Standard, and Poor credit scores.
# * A count plot is best for showing how many customers belong to each category and comparing them by credit score.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights from the chart:-
#
# * Low spent small-value payments has the highest number of customers, especially in the Standard credit-score group.
# * High spent medium-value payments also has a large number of Standard-credit-score customers.
# * Good credit-score customers have lower customer counts across most payment-behaviour categories.
# * Poor credit-score customers are more concentrated in low spent small-value and medium-value payment behaviours.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:-
#
# * The insight can help the business understand customer payment preferences and design suitable products, offers, and payment options for different credit-score groups.
#
# Positive business impact:-
#
# * The large number of Standard and Poor credit-score customers in some payment-behaviour categories may indicate higher credit risk. If these customers have poor repayment behaviour, the business could face increased defaults and financial losses.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Credit_Score', hue='Payment_of_Min_Amount')
plt.title('Credit Score Distribution by Payment of Minimum Amount')
plt.xlabel('Credit Score')
plt.ylabel('Count')
plt.legend(title='Payment of Min Amount')
plt.show()

# %%
df.columns

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Credit_Score is categorical: Good, Standard, Poor.
# * Payment_of_Min_Amount is also categorical: Yes, No, NM.
# * A count plot shows the number of customers in each combination.
# * It makes it easy to compare minimum-payment behavior across credit-score groups.
# * A count plot is best for comparing customer counts between two categorical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights from the chart:-
#
# * Standard credit-score customers have the highest number of customers who pay the minimum amount (Yes).
# * Poor credit-score customers also have a large number of customers who pay the minimum amount.
# * Good credit-score customers have relatively fewer customers paying the minimum amount.
# * Overall, paying the minimum amount is much more common among Standard and Poor credit-score customers.
# * This may indicate that these groups could have higher repayment difficulty or greater dependence on minimum payments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:-
#
# * The insight can help the business identify customers who may need repayment support, especially Standard and Poor credit-score customers who frequently pay only the minimum amount. This can help reduce default risk and financial losses.
#
# Negative business impact:-
#
# * If the business restricts credit for all customers who pay the minimum amount, it may lose potential customers and revenue.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Credit_Score', hue='Payment_Behaviour')
plt.title('Credit Score Distribution by Payment_Behaviour')
plt.xlabel('Credit Score')
plt.ylabel('Count')
plt.legend(title='Payment_Behaviour')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Countplot was selected to compare the frequency of different Payment Behaviours across Credit Score categories.
#
# A count plot is suitable for comparing customer counts across two categorical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights from the chart:-
#
# * Low_spent_Small_value_payments has the highest number of customers, especially in the Standard credit-score group.
# * High_spent_Medium_value_payments is the second-highest payment behaviour among Standard customers.
# * Standard credit-score customers have the highest customer count across almost all payment-behaviour categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:-
#
# * The insight can help the business understand customer payment preferences and create targeted offers or payment plans for different credit-score groups.
#
# Negative business impact:-
#
# * The high number of Standard and Poor credit-score customers in some payment-behaviour categories may indicate higher credit risk. If these customers have difficulty managing payments, the business may face more defaults and financial losses.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Credit_Mix', hue='Credit_Score')
plt.title('Credit Score Distribution by Credit_Mix')
plt.xlabel('Credit_Mix')
plt.ylabel('Count')
plt.legend(title='Credit_Score')
plt.show()

# %%
df.columns

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Credit_Mix is a categorical variable: Good, Standard, Bad.
# * Credit_Score is also categorical: Good, Standard, Poor.
# * A count plot shows the number of customers in each Credit_Mix category.
# * Using hue='Credit_Score' makes it easy to compare credit-score groups within each credit-mix category.
# * A count plot is suitable for comparing customer counts across two categorical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights from the chart:-
#
# * Standard Credit Score customers are highest in the Standard Credit Mix category, with around 33,000 customers.
# * Good Credit Score customers are highest in the Good Credit Mix category, with around 15,000 customers.
# * Poor Credit Score customers are highest in the Bad Credit Mix category, with around 14,000 customers.
# * This shows a strong relationship between Credit Mix and Credit Score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insights from the chart:-
#
# * The insight can help the business assess customer credit risk. Customers with a Good Credit Mix and Good Credit Score can be targeted for better offers, while higher-risk customers can receive suitable credit limits.
#
#
# Negative from the chart:-
#
# * Customers with a Bad Credit Mix and Poor Credit Score may have a higher risk of loan default or delayed repayment, which can cause financial losses.
# * However, rejecting all customers with a Bad Credit Mix could reduce potential revenue.

# %% [markdown]
#  Chart - 13 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
numerical_cols = ['Age','Annual_Income','Num_of_Loan', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Outstanding_Debt']
corr_data = df[numerical_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_data, annot=True, fmt='.2f', cmap='coolwarm', center=0,
            square=True, linewidths=1, cbar_kws={"shrink": 0.8})
plt.title('Correlation Heatmap: Numerical Variables', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

print("Strongest positive correlations:")
corr_flat = corr_data.unstack().sort_values(ascending=False)
corr_flat = corr_flat[corr_flat < 1.0]  # Exclude self-correlation
print(corr_flat.head(5))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a Correlation Heatmap because it is suitable for analyzing the relationships between multiple numerical variables at the same time. It clearly shows the strength and direction of correlations, making it easy to identify which variables have strong positive, negative, or weak relationships with each other.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the average Annual Income differs across the Credit Score categories. Customers with a Good Credit Score generally have higher average income, while customers with a Poor Credit Score tend to have comparatively lower average income. This suggests that Annual Income may have some relationship with creditworthiness, although income alone does not determine the Credit Score.

# %% [markdown]
# #### Chart - 14 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df[['Age','Annual_Income',
    'Delay_from_due_date',
    'Num_of_Delayed_Payment',
    'Outstanding_Debt',
    'Credit_Utilization_Ratio',
    'Total_EMI_per_month',
    'Credit_Score']], hue='Credit_Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * It shows relationships between multiple numerical variables at the same time.
# * It helps identify correlations, patterns, and possible outliers.
# * The diagonal shows the distribution of each variable.
# * hue='Credit_Score' allows comparison between Good, Standard, and Poor customers.
# * A pair plot is useful for understanding relationships between many variables and how they differ by credit score.
#
#
#
#
#
# A pairplot shows relationships between multiple numerical variables and uses Credit_Score to distinguish the categories (Good, Standard, Poor).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights from the chart:-
#
# * Annual Income: Standard credit-score customers are more widely distributed, while Good customers generally have lower income ranges.
# * Delay from Due Date: Poor and Standard customers tend to have more delayed payments than Good customers.
# * Number of Delayed Payments: Poor customers generally show higher delayed-payment counts, indicating greater repayment risk.
# * Outstanding Debt: Standard and Poor customers tend to have higher outstanding debt than Good customers.
# * Credit Utilization Ratio: The groups overlap considerably, so there is no very strong separation based on utilization alone.
# * Total EMI per Month: There appears to be a positive relationship with Annual Income—higher-income customers generally have higher EMI amounts.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# I would suggest the client to use the insights from the data analysis to identify the major factors affecting customers' credit scores and improve credit risk assessment.
# The client should focus on the following:
#
# 1.  Monitor delayed payments :- Customers with frequent delayed payments should be identified and monitored because payment history can affect creditworthiness.
# 2. Control outstanding debt :- Customers with high outstanding debt should be identified and provided with suitable repayment or financial-management options.
# 3.   Analyze credit utilization :- High credit utilization should be monitored to identify customers who may have a higher financial burden.
# 4.   Evaluate credit mix and payment behaviour :- Credit Mix and Payment Behaviour should be analyzed to understand differences between Good, Standard, and Poor credit-score customers.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Credit Score Classification project provided valuable insights into the financial behaviour of customers and the factors associated with their credit scores. Through data cleaning, exploratory data analysis, feature engineering, and visualization, important relationships between credit scores and variables such as income, loans, outstanding debt, delayed payments, credit utilization, credit mix, and payment behaviour were identified.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
